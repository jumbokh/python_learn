# %% [markdown]
# <a href="https://colab.research.google.com/github/jumbokh/python_learn/blob/master/notebooks/3_%E6%96%87%E5%AD%97%E8%BD%89%E8%AA%9E%E9%9F%B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #文字轉語音
# https://twgo.io/feban
#
# 本套件使用Google文字轉語音gTTS套件，將文字轉成mp3發音格式，可以指定發音國別
# 程式分成以下步驟
# 0. 請記得製作副本到你自己的Colab
# 1. 安裝相關套件
# 2. 匯入相關套件
# 3. 執行翻譯

# %% [markdown]
# 步驟1：安裝gtts套件

# %%
# !pip install gtts

# %% [markdown]
# 步驟2：匯入相依性套件

# %%
from IPython.display import Audio
from IPython.display import display
from gtts import gTTS

# %% [markdown]
# 步驟3：執行文字轉發音

# %%
text = '女粉絲心碎了！效力於洛杉磯道奇隊的日本中場大谷翔平早些時候在個人IG上宣布結婚。消息曝光後，令所有粉絲震驚。'
tts = gTTS(text, lang='en', slow=False)
tts.save('1.wav')
sound_file = '1.wav'
wn = Audio(sound_file, autoplay=True) ##
display(wn)##
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
